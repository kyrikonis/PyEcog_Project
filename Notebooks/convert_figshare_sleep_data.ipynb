# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s - %(message)s')

# %%
from pyecog2.convert_figshare_sleep_data import convert_animal_to_multimodal

# %%
# Convert M1EXP1
convert_animal_to_multimodal(
    dat_file='data/M1EXP1.dat',
    eeg_file='data/M1EXP1.eeg',
    output_folder='data/converted/M1EXP1'
)
# Out:
# INFO - Converting M1EXP1
# INFO - Read data/M1EXP1.dat: 86400 epochs, temp recorded: False
# INFO - Created metadata file: data/M1EXP1.meta (modality: voltage, sample frequency: 200 Hz)
# INFO - Created metadata file: data/converted/M1EXP1/M1EXP1_EMG.meta (modality: variance, sample frequency: 0.25 Hz)
# INFO -   M1EXP1: temperature not recorded, skipping
# INFO - Created metadata file: data/converted/M1EXP1/M1EXP1_SleepScore.meta (modality: categorical, sample frequency: 0.25 Hz)
# INFO -   wake: 47407 epochs
# INFO -   NREM: 32310 epochs
# INFO -   REM: 4302 epochs
# {'EEG': 'data/M1EXP1.meta',
#  'EMG': 'data/converted/M1EXP1/M1EXP1_EMG.meta',
#  'SleepScore': 'data/converted/M1EXP1/M1EXP1_SleepScore.meta'}

# %%
# Convert M1EXP2
convert_animal_to_multimodal(
    dat_file='data/M1EXP2.dat',
    eeg_file='data/M1EXP2.eeg',
    output_folder='data/converted/M1EXP2'
)
# Out:
# INFO - Converting M1EXP2
# INFO - Read data/M1EXP2.dat: 86400 epochs, temp recorded: True
# INFO - Created metadata file: data/M1EXP2.meta (modality: voltage, sample frequency: 200 Hz)
# INFO - Created metadata file: data/converted/M1EXP2/M1EXP2_EMG.meta (modality: variance, sample frequency: 0.25 Hz)
# INFO - Created metadata file: data/converted/M1EXP2/M1EXP2_Temperature.meta (modality: temperature, sample frequency: 0.25 Hz)
# INFO - Created metadata file: data/converted/M1EXP2/M1EXP2_SleepScore.meta (modality: categorical, sample frequency: 0.25 Hz)
# INFO -   wake: 44881 epochs
# INFO -   NREM: 33124 epochs
# INFO -   REM: 4520 epochs
# {'EEG': 'data/M1EXP2.meta',
#  'EMG': 'data/converted/M1EXP2/M1EXP2_EMG.meta',
#  'Temperature': 'data/converted/M1EXP2/M1EXP2_Temperature.meta',
#  'SleepScore': 'data/converted/M1EXP2/M1EXP2_SleepScore.meta'}
